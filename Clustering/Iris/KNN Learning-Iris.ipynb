# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn import preprocessing, neighbors, model_selection
from sklearn.model_selection import train_test_split, cross_validate

# %%
df = pd.read_csv('iris.data')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.set_theme(style='whitegrid')
ax = sns.barplot(x=df['class'], y=df['sepal_length'], ci="sd")
ax.set(xlabel = 'Class')
ax.set(ylabel='Sepal Length (cm)')
# Out:
# [Text(0, 0.5, 'Sepal Length (cm)')]

# %%
sns.set_theme(style='whitegrid')
ax = sns.barplot(x=df['class'], y=df['sepal_width'], ci="sd")
ax.set(xlabel = 'Class')
ax.set(ylabel='Sepal Width (cm)')
# Out:
# [Text(0, 0.5, 'Sepal Width (cm)')]

# %%
sns.set_theme(style='whitegrid')
ax = sns.barplot(x=df['class'], y=df['petal_length'], ci="sd")
ax.set(xlabel = 'Class')
ax.set(ylabel='Petal Length (cm)')
# Out:
# [Text(0, 0.5, 'Petal Length (cm)')]

# %%
sns.set_theme(style='whitegrid')
ax = sns.barplot(x=df['class'], y=df['petal_width'], ci="sd")
ax.set(xlabel = 'Class')
ax.set(ylabel='Petal Width (cm)')
# Out:
# [Text(0, 0.5, 'Petal Width (cm)')]

# %%
sns.violinplot(x=df['class'], y=df['sepal_length'])
ax.set(xlabel = 'Class')
ax.set(ylabel='Sepal Length (cm)')
# Out:
# [Text(20.200000000000003, 0.5, 'Sepal Length (cm)')]

# %%
sns.violinplot(x=df['class'], y=df['sepal_width'])
ax.set(xlabel = 'Class')
ax.set(ylabel='Sepal Width (cm)')
# Out:
# [Text(20.200000000000003, 0.5, 'Sepal Width (cm)')]

# %%
sns.violinplot(x=df['class'], y=df['petal_length'])
ax.set(xlabel = 'Class')
ax.set(ylabel='Petal Length (cm)')
# Out:
# [Text(20.200000000000003, 0.5, 'Petal Length (cm)')]

# %%
sns.violinplot(x=df['class'], y=df['petal_width'])
ax.set(xlabel = 'Class')
ax.set(ylabel='Petal Width (cm)')
# Out:
# [Text(20.200000000000003, 0.5, 'Petal Width (cm)')]

# %%
sns.jointplot(df['sepal_width'], df['sepal_length'], kind="kde", size=7)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(df['petal_width'], df['petal_length'], kind="kde", size=7)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.heatmap(df.corr(), annot = True)

# %%
sns.boxplot(x='class', y='sepal_length',data=df,palette='winter')

# %%
sns.boxplot(x='class', y='petal_length',data=df,palette='winter')

# %%
sns.boxplot(x='class', y='sepal_width',data=df,palette='winter')

# %%
sns.boxplot(x='class', y='petal_width',data=df,palette='winter')

# %%
X = np.array(df.drop(['class'],1))

# %%
y = np.array(df['class'])

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X,y,test_size = 0.2)

# %%
clf = neighbors.KNeighborsClassifier()

# %%
clf.fit(X_train, y_train)

# %%
accuracy = clf.score(X_test, y_test)
print(accuracy)

# %%
myData = np.array([[3.4, 2.0, 1.5, 2.2]])

# %%
myClassPrediction = clf.predict(myData)
print(myClassPrediction)
